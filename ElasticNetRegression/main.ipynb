# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('CarPrice_Assignment.csv')
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
dataset.shape
# Out:
# (205, 26)

# %%
dataset.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
i = 1
plt.figure(figsize=(15,45))
for column in dataset:
    plt.subplot(9 , 3 , i)
    plt.scatter(dataset["price"], dataset[column])
    i+=1
 
plt.show()

# %%
dataset.corr()
# Out:
# /tmp/ipykernel_12003/2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in dataset:
    if dataset[column].dtype == 'object':
        dataset[column] = label_encoder.fit_transform(dataset[column])
        
dataset.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
dataset.corr()
# Out:
#                     car_ID  symboling   CarName  fueltype  aspiration  \
# car_ID            1.000000  -0.151621  0.967077 -0.125568    0.067729
# symboling        -0.151621   1.000000 -0.107095  0.194311   -0.059866
# CarName           0.967077  -0.107095  1.000000 -0.069435    0.019914
# fueltype         -0.125568   0.194311 -0.069435  1.000000   -0.401397
# aspiration        0.067729  -0.059866  0.019914 -0.401397    1.000000
# doornumber       -0.190352   0.664073 -0.171745  0.191491   -0.031792
# carbody           0.098303  -0.596135  0.099691 -0.147853    0.063028
# drivewheel        0.051406  -0.041671 -0.016129 -0.132257    0.066465
# enginelocation    0.051483   0.212471  0.055968  0.040070   -0.057191
# wheelbase         0.129729  -0.531954  0.014550 -0.308346    0.257611
# carlength         0.170636  -0.357612  0.053016 -0.212679    0.234539
# carwidth          0.052387  -0.232919 -0.075349 -0.233880    0.300567
# ...

# %%
from sklearn.model_selection import train_test_split
x = dataset.drop("price", axis = 1)
y = dataset['price']
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state=42)

# %%
from sklearn.linear_model import ElasticNet , LinearRegression
model = ElasticNet(alpha=1, l1_ratio=0.4)
model2 = LinearRegression()
model.fit(x_train, y_train)
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred_train = model.predict(x_train)
y_pred2 = model2.predict(x_test)
y_pred_train2 = model2.predict(x_train)

# %%
model.coef_
# Out:
# array([  28.07141976,  115.61370782,  -60.71582982,    4.46611869,
#         -74.33054865, -167.76447991, -544.1600518 ,  215.40204409,
#         238.53574494,   88.53793243,  -10.42244971,  191.13812868,
#         278.78855455,    1.98907214,  273.75025356,  -42.61921248,
#          85.04761752,   -4.67026081,   58.28802787, -366.05174961,
#         266.73471157,   48.34206266,    1.99356482, -189.59330534,
#         106.0051405 ])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
score = r2_score(y_test,y_pred)
print("R2 score is ",score)
print("Mean Squared Error is ", mean_squared_error(y_test, y_pred))
print("Mean Squared Error on train data is ", mean_squared_error(y_train, y_pred_train))
print("Mean Absolute Error is ", mean_absolute_error(y_test, y_pred))
print("Mean Absolute Percentage Error is ", mean_absolute_percentage_error(y_test, y_pred))
# Out:
# R2 score is  0.8564786408084755
# Mean Squared Error is  11330153.176692558
# Mean Squared Error on train data is  7794973.029071502
# Mean Absolute Error is  2290.73594998855
# Mean Absolute Percentage Error is  0.20979777754566606

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
score = r2_score(y_test,y_pred2)
print("R2 score is ",score)
print("Mean Squared Error is ", mean_squared_error(y_test, y_pred2))
print("Mean Squared Error on train data is ", mean_squared_error(y_train, y_pred_train2))
print("Mean Absolute Error is ", mean_absolute_error(y_test, y_pred2))
print("Mean Absolute Percentage Error is ", mean_absolute_percentage_error(y_test, y_pred2))
# Out:
# R2 score is  0.8441158536668149
# Mean Squared Error is  12306121.302934581
# Mean Squared Error on train data is  5346263.283511498
# Mean Absolute Error is  2087.306212322847
# Mean Absolute Percentage Error is  0.17947573515999835
